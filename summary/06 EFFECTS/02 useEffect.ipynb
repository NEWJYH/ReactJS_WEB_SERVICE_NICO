# %% [markdown]
# # useEffect
#
#
# ## useState로 값을 변경해도 재랜더링이 일어나지 않도록

# %% [markdown]
# useEffect(func, [])
#
#  - 빈 배열을 넣으면 처음 랜더링될 때 단 한번만 호출됨

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
